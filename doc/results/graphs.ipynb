# %%
import csv
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
import matplotlib

mypath = '.'

# %%
def all_graphs():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    for file_name in files:
        sizes = []
        times = []
        gflops = []
        with open(join(mypath, file_name), 'rb') as csvfile:
            reader = csv.reader(csvfile, delimiter='|')
            for row in reader:
                size = int(row[0])
                sizes.append(size)
                time = float(row[1])
                times.append(time)
                gflop = float(row[2])
                gflops.append(gflop)

            plt.figure("{}_1".format(file_name))
            plt.title(file_name)
            plt.xlabel('size')
            plt.ylabel('seconds')
            plt.grid(True)
            plt.legend()
            plt.plot(sizes, times, lw=2, marker='o', label=file_name)

            plt.figure("{}_2".format(file_name))
            plt.title(file_name)
            plt.xlabel('size')
            plt.ylabel('gflop/seconds')
            plt.grid(True)
            plt.legend()
            plt.plot(sizes, gflops, lw=2, color='r', marker='o', label=file_name)
    plt.show()

all_graphs()
# Out:
# /Users/diegor/Work/virtualenv/notebook/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /Users/diegor/Work/virtualenv/notebook/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
def blocking_graphs_times():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    plt.title("blocking experiments")
    plt.xlabel('size')
    plt.ylabel('seconds')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        if 'nonblock' not in file_name:
            sizes = []
            times = []
            gflops = []
            with open(join(mypath, file_name), 'rb') as csvfile:
                reader = csv.reader(csvfile, delimiter='|')
                for row in reader:
                    size = int(row[0])
                    sizes.append(size)
                    time = float(row[1])
                    times.append(time)
                    gflop = float(row[2])
                    gflops.append(gflop)
            plt.plot(sizes, times, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()

def blocking_graphs_gflops():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    plt.title("blocking experiments")
    plt.xlabel('size')
    plt.ylabel('gflop/s')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        if 'nonblock' not in file_name:
            sizes = []
            times = []
            gflops = []
            with open(join(mypath, file_name), 'rb') as csvfile:
                reader = csv.reader(csvfile, delimiter='|')
                for row in reader:
                    size = int(row[0])
                    sizes.append(size)
                    time = float(row[1])
                    times.append(time)
                    gflop = float(row[2])
                    gflops.append(gflop)
            plt.plot(sizes, gflops, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()
            
blocking_graphs_times()
blocking_graphs_gflops()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-3-ac2440d8f0be> in <module>()
#      53     plt.show()
#      54
# ---> 55 blocking_graphs_times()
#      56 blocking_graphs_gflops()
#
# <ipython-input-3-ac2440d8f0be> in blocking_graphs_times()
#      14             with open(join(mypath, file_name), 'rb') as csvfile:
#      15                 reader = csv.reader(csvfile, delimiter='|')
# ---> 16                 for row in reader:
#      17                     size = int(row[0])
#      18                     sizes.append(size)
#
# Error: line contains NULL byte

# %%
def non_blocking_graphs_times():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    plt.title("non blocking experiments")
    plt.xlabel('size')
    plt.ylabel('seconds')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        if 'nonblock' in file_name or 'serial' in file_name:
            sizes = []
            times = []
            gflops = []
            with open(join(mypath, file_name), 'rb') as csvfile:
                reader = csv.reader(csvfile, delimiter='|')
                for row in reader:
                    size = int(row[0])
                    sizes.append(size)
                    time = float(row[1])
                    times.append(time)
                    gflop = float(row[2])
                    gflops.append(gflop)
            plt.plot(sizes, times, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()

def non_blocking_graphs_gflops():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    plt.title("non blocking experiments")
    plt.xlabel('size')
    plt.ylabel('gflop/s')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        if 'nonblock' in file_name or 'serial' in file_name:
            sizes = []
            times = []
            gflops = []
            with open(join(mypath, file_name), 'rb') as csvfile:
                reader = csv.reader(csvfile, delimiter='|')
                for row in reader:
                    size = int(row[0])
                    sizes.append(size)
                    time = float(row[1])
                    times.append(time)
                    gflop = float(row[2])
                    gflops.append(gflop)
            plt.plot(sizes, gflops, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()
            
non_blocking_graphs_times()
non_blocking_graphs_gflops()

# %%
def openmp_graphs_times():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    plt.title("OpenMP experiments")
    plt.xlabel('size')
    plt.ylabel('seconds')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        if 'openmp' in file_name or 'serial' in file_name:
            sizes = []
            times = []
            gflops = []
            with open(join(mypath, file_name), 'rb') as csvfile:
                reader = csv.reader(csvfile, delimiter='|')
                for row in reader:
                    size = int(row[0])
                    sizes.append(size)
                    time = float(row[1])
                    times.append(time)
                    gflop = float(row[2])
                    gflops.append(gflop)
            plt.plot(sizes, times, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()

def openmp_graphs_gflops():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    plt.title("OpenMP experiments")
    plt.xlabel('size')
    plt.ylabel('gflop/s')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        if 'openmp' in file_name or 'serial' in file_name:
            sizes = []
            times = []
            gflops = []
            with open(join(mypath, file_name), 'rb') as csvfile:
                reader = csv.reader(csvfile, delimiter='|')
                for row in reader:
                    size = int(row[0])
                    sizes.append(size)
                    time = float(row[1])
                    times.append(time)
                    gflop = float(row[2])
                    gflops.append(gflop)
            plt.plot(sizes, gflops, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=7)
    plt.show()
            
openmp_graphs_times()
openmp_graphs_gflops()

# %%
def cblas_graphs_times():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    plt.title("CBLAS experiments")
    plt.xlabel('size')
    plt.ylabel('seconds')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        if 'cblas' in file_name or 'serial' in file_name:
            sizes = []
            times = []
            gflops = []
            with open(join(mypath, file_name), 'rb') as csvfile:
                reader = csv.reader(csvfile, delimiter='|')
                for row in reader:
                    size = int(row[0])
                    sizes.append(size)
                    time = float(row[1])
                    times.append(time)
                    gflop = float(row[2])
                    gflops.append(gflop)
            plt.plot(sizes, times, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()

def cblas_graphs_gflops():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    plt.title("CBLAS experiments")
    plt.xlabel('size')
    plt.ylabel('gflop/s')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        if 'cblas' in file_name or 'serial' in file_name:
            sizes = []
            times = []
            gflops = []
            with open(join(mypath, file_name), 'rb') as csvfile:
                reader = csv.reader(csvfile, delimiter='|')
                for row in reader:
                    size = int(row[0])
                    sizes.append(size)
                    time = float(row[1])
                    times.append(time)
                    gflop = float(row[2])
                    gflops.append(gflop)
            plt.plot(sizes, gflops, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()
            
cblas_graphs_times()
cblas_graphs_gflops()

# %%
def all_graphs_times():
    files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.startswith('x.mm')]
    plt.title("All experiments")
    plt.xlabel('size')
    plt.ylabel('seconds')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        sizes = []
        times = []
        gflops = []
        with open(join(mypath, file_name), 'rb') as csvfile:
            reader = csv.reader(csvfile, delimiter='|')
            for row in reader:
                size = int(row[0])
                sizes.append(size)
                time = float(row[1])
                times.append(time)
                gflop = float(row[2])
                gflops.append(gflop)
        plt.plot(sizes, times, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()

def all_graphs_gflops():
    plt.title("All experiments")
    plt.xlabel('size')
    plt.ylabel('gflop/s')
    plt.grid(True)
    
    legend_items = []
    for file_name in files:
        sizes = []
        times = []
        gflops = []
        with open(join(mypath, file_name), 'rb') as csvfile:
            reader = csv.reader(csvfile, delimiter='|')
            for row in reader:
                size = int(row[0])
                sizes.append(size)
                time = float(row[1])
                times.append(time)
                gflop = float(row[2])
                gflops.append(gflop)
        plt.plot(sizes, gflops, lw=2, marker='o', label=file_name)
    
    plt.legend(loc=2)
    plt.show()
            
all_graphs_times()
all_graphs_gflops()
